# %% [markdown]
# <a href="https://colab.research.google.com/github/259mit/AI/blob/master/CS50/Learning/J002_Learning_Nim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import time

# %%
class Nim():

    def __init__(self, initial=[1, 3, 5, 7]):
        self.piles = initial.copy()
        self.player = 0
        self.winner = None

    @classmethod
    def available_actions(cls, piles):
        actions = set()
        for i, pile in enumerate(piles):
            for j in range(1, pile + 1):
                actions.add((i, j))
        return actions

    @classmethod
    def other_player(cls, player):
        return 0 if player == 1 else 1

    def switch_player(self):
        self.player = Nim.other_player(self.player)

    def move(self, action):
        pile, count = action

        # Check for errors
        if self.winner is not None:
            raise Exception("Game already won")
        elif pile < 0 or pile >= len(self.piles):
            raise Exception("Invalid pile")
        elif count < 1 or count > self.piles[pile]:
            raise Exception("Invalid number of objects")

        # Update pile
        self.piles[pile] -= count
        self.switch_player()

        # Check for a winner
        if all(pile == 0 for pile in self.piles):
            self.winner = self.player

# %%
def train(n):
    player = NimAI()

    # Play n games
    for i in range(n):
        print(f"Playing training game {i + 1}")
        game = Nim()

        # Keep track of last move made by either player
        last = {
            0: {"state": None, "action": None},
            1: {"state": None, "action": None}
        }

        # Game loop
        while True:

            # Keep track of current state and action
            state = game.piles.copy()
            action = player.choose_action(game.piles)

            # Keep track of last state and action
            last[game.player]["state"] = state
            last[game.player]["action"] = action

            # Make move
            game.move(action)
            new_state = game.piles.copy()

            # When game is over, update Q values with rewards
            if game.winner is not None:
                player.update(state, action, new_state, -1)
                player.update(
                    last[game.player]["state"],
                    last[game.player]["action"],
                    new_state,
                    1
                )
                break

            # If game is continuing, no rewards yet
            elif last[game.player]["state"] is not None:
                player.update(
                    last[game.player]["state"],
                    last[game.player]["action"],
                    new_state,
                    0
                )

    print("Done training")

    # Return the trained AI
    return player

# %%
def play(ai, human_player=None):
    # If no player order set, choose human's order randomly
    if human_player is None:
        human_player = random.randint(0, 1)

    # Create new game
    game = Nim()

    # Game loop
    while True:

        # Print contents of piles
        print()
        print("Piles:")
        for i, pile in enumerate(game.piles):
            print(f"Pile {i}: {pile}")
        print()

        # Compute available actions
        available_actions = Nim.available_actions(game.piles)
        time.sleep(1)

        # Let human make a move
        if game.player == human_player:
            print("Your Turn")
            while True:
                pile = int(input("Choose Pile: "))
                count = int(input("Choose Count: "))
                if (pile, count) in available_actions:
                    break
                print("Invalid move, try again.")

        # Have AI make a move
        else:
            print("AI's Turn")
            pile, count = ai.choose_action(game.piles, epsilon=False)
            print(f"AI chose to take {count} from pile {pile}.")

        # Make move
        game.move((pile, count))

        # Check for winner
        if game.winner is not None:
            print()
            print("GAME OVER")
            winner = "Human" if game.winner == human_player else "AI"
            print(f"Winner is {winner}")
            return

# %%
class NimAI():

    def __init__(self, alpha=0.5, epsilon=0.1):
        self.q = dict()
        self.alpha = alpha
        self.epsilon = epsilon

    def update(self, old_state, action, new_state, reward):
        old = self.get_q_value(old_state, action)
        best_future = self.best_future_reward(new_state)
        self.update_q_value(old_state, action, old, reward, best_future)

    def get_q_value(self, state, action):
        if (tuple(state), action) not in self.q:
            return 0
        
        return self.q[tuple(state), action]

    def update_q_value(self, state, action, old_q, reward, future_rewards):
        self.q[tuple(state), action] = old_q + self.alpha * (reward + future_rewards - old_q)

    def best_future_reward(self, state):
        best_reward = 0

        for available_action in Nim.available_actions(state):
            if self.get_q_value(state, available_action) > best_reward:
                best_reward = self.get_q_value(state, available_action)

        return best_reward

    def choose_action(self, state, epsilon=True):
        available_actions = Nim.available_actions(state)

        # Choose random available action
        if epsilon and random.random() <= self.epsilon:
            return random.sample(available_actions, 1)[0]
        
        # Otherwise choose best available action
        best_reward = -math.inf

        for available_action in available_actions:
            if self.get_q_value(state, available_action) > best_reward:
                best_reward = self.get_q_value(state, available_action)
                best_action = available_action

        return best_action

# %%
ai = train(10000)
play(ai)
# Out:
# Streaming output truncated to the last 5000 lines.
# Playing training game 5054
# Playing training game 5055
# Playing training game 5056
# Playing training game 5057
# Playing training game 5058
# Playing training game 5059
# Playing training game 5060
# Playing training game 5061
# Playing training game 5062
# Playing training game 5063
# Playing training game 5064
# Playing training game 5065
# Playing training game 5066
# Playing training game 5067
# Playing training game 5068
# Playing training game 5069
# Playing training game 5070
# Playing training game 5071
# Playing training game 5072
# Playing training game 5073
# Playing training game 5074
# Playing training game 5075
# Playing training game 5076
# Playing training game 5077
# Playing training game 5078
# Playing training game 5079
# Playing training game 5080
# Playing training game 5081
# Playing training game 5082
# Playing training game 5083
# Playing training game 5084
# Playing training game 5085
# Playing training game 5086
# Playing training game 5087
# Playing training game 5088
# Playing training game 5089
# Playing training game 5090
# Playing training game 5091
# Playing training game 5092
# Playing training game 5093
# Playing training game 5094
# Playing training game 5095
# Playing training game 5096
# Playing training game 5097
# Playing training game 5098
# Playing training game 5099
# Playing training game 5100
# Playing training game 5101
# Playing training game 5102
# Playing training game 5103
# Playing training game 5104
# Playing training game 5105
# Playing training game 5106
# Playing training game 5107
# Playing training game 5108
# Playing training game 5109
# Playing training game 5110
# Playing training game 5111
# Playing training game 5112
# Playing training game 5113
# Playing training game 5114
# Playing training game 5115
# Playing training game 5116
# Playing training game 5117
# Playing training game 5118
# Playing training game 5119
# Playing training game 5120
# Playing training game 5121
# Playing training game 5122
# Playing training game 5123
# Playing training game 5124
# Playing training game 5125
# Playing training game 5126
# Playing training game 5127
# Playing training game 5128
# Playing training game 5129
# Playing training game 5130
# Playing training game 5131
# Playing training game 5132
# Playing training game 5133
# Playing training game 5134
# Playing training game 5135
# Playing training game 5136
# Playing training game 5137
# Playing training game 5138
# Playing training game 5139
# Playing training game 5140
# Playing training game 5141
# Playing training game 5142
# Playing training game 5143
# Playing training game 5144
# Playing training game 5145
# Playing training game 5146
# Playing training game 5147
# Playing training game 5148
# Playing training game 5149
# Playing training game 5150
# Playing training game 5151
# Playing training game 5152
# Playing training game 5153
# Playing training game 5154
# Playing training game 5155
# Playing training game 5156
# Playing training game 5157
# Playing training game 5158
# Playing training game 5159
# Playing training game 5160
# Playing training game 5161
# Playing training game 5162
# Playing training game 5163
# Playing training game 5164
# Playing training game 5165
# Playing training game 5166
# Playing training game 5167
# Playing training game 5168
# Playing training game 5169
# Playing training game 5170
# Playing training game 5171
# Playing training game 5172
# Playing training game 5173
# Playing training game 5174
# Playing training game 5175
# Playing training game 5176
# Playing training game 5177
# Playing training game 5178
# Playing training game 5179
# Playing training game 5180
# Playing training game 5181
# Playing training game 5182
# Playing training game 5183
# Playing training game 5184
# Playing training game 5185
# Playing training game 5186
# Playing training game 5187
# Playing training game 5188
# Playing training game 5189
# Playing training game 5190
# Playing training game 5191
# Playing training game 5192
# Playing training game 5193
# Playing training game 5194
# Playing training game 5195
# Playing training game 5196
# Playing training game 5197
# Playing training game 5198
# Playing training game 5199
# Playing training game 5200
# Playing training game 5201
# Playing training game 5202
# Playing training game 5203
# Playing training game 5204
# Playing training game 5205
# Playing training game 5206
# Playing training game 5207
# Playing training game 5208
# Playing training game 5209
# Playing training game 5210
# Playing training game 5211
# Playing training game 5212
# Playing training game 5213
# Playing training game 5214
# Playing training game 5215
# Playing training game 5216
# Playing training game 5217
# Playing training game 5218
# Playing training game 5219
# Playing training game 5220
# Playing training game 5221
# Playing training game 5222
# Playing training game 5223
# Playing training game 5224
# Playing training game 5225
# Playing training game 5226
# Playing training game 5227
# Playing training game 5228
# Playing training game 5229
# Playing training game 5230
# Playing training game 5231
# Playing training game 5232
# Playing training game 5233
# Playing training game 5234
# Playing training game 5235
# Playing training game 5236
# Playing training game 5237
# Playing training game 5238
# Playing training game 5239
# Playing training game 5240
# Playing training game 5241
# Playing training game 5242
# Playing training game 5243
# Playing training game 5244
# Playing training game 5245
# Playing training game 5246
# Playing training game 5247
# Playing training game 5248
# Playing training game 5249
# Playing training game 5250
# Playing training game 5251
# Playing training game 5252
# Playing training game 5253
# Playing training game 5254
# Playing training game 5255
# Playing training game 5256
# Playing training game 5257
# Playing training game 5258
# Playing training game 5259
# Playing training game 5260
# Playing training game 5261
# Playing training game 5262
# Playing training game 5263
# Playing training game 5264
# Playing training game 5265
# Playing training game 5266
# Playing training game 5267
# Playing training game 5268
# Playing training game 5269
# Playing training game 5270
# Playing training game 5271
# Playing training game 5272
# Playing training game 5273
# Playing training game 5274
# Playing training game 5275
# Playing training game 5276
# Playing training game 5277
# Playing training game 5278
# Playing training game 5279
# Playing training game 5280
# Playing training game 5281
# Playing training game 5282
# Playing training game 5283
# Playing training game 5284
# Playing training game 5285
# Playing training game 5286
# Playing training game 5287
# Playing training game 5288
# Playing training game 5289
# Playing training game 5290
# Playing training game 5291
# Playing training game 5292
# Playing training game 5293
# Playing training game 5294
# Playing training game 5295
# Playing training game 5296
# Playing training game 5297
# Playing training game 5298
# Playing training game 5299
# Playing training game 5300
# Playing training game 5301
# Playing training game 5302
# Playing training game 5303
# Playing training game 5304
# Playing training game 5305
# Playing training game 5306
# Playing training game 5307
# Playing training game 5308
# Playing training game 5309
# Playing training game 5310
# Playing training game 5311
# Playing training game 5312
# Playing training game 5313
# Playing training game 5314
# Playing training game 5315
# Playing training game 5316
# Playing training game 5317
# Playing training game 5318
# Playing training game 5319
# Playing training game 5320
# Playing training game 5321
# Playing training game 5322
# Playing training game 5323
# Playing training game 5324
# Playing training game 5325
# Playing training game 5326
# Playing training game 5327
# Playing training game 5328
# Playing training game 5329
# Playing training game 5330
# Playing training game 5331
# Playing training game 5332
# Playing training game 5333
# Playing training game 5334
# Playing training game 5335
# Playing training game 5336
# Playing training game 5337
# Playing training game 5338
# Playing training game 5339
# Playing training game 5340
# Playing training game 5341
# Playing training game 5342
# Playing training game 5343
# Playing training game 5344
# Playing training game 5345
# Playing training game 5346
# Playing training game 5347
# Playing training game 5348
# Playing training game 5349
# Playing training game 5350
# Playing training game 5351
# Playing training game 5352
# Playing training game 5353
# Playing training game 5354
# Playing training game 5355
# Playing training game 5356
# Playing training game 5357
# Playing training game 5358
# Playing training game 5359
# Playing training game 5360
# Playing training game 5361
# Playing training game 5362
# Playing training game 5363
# Playing training game 5364
# Playing training game 5365
# Playing training game 5366
# Playing training game 5367
# Playing training game 5368
# Playing training game 5369
# Playing training game 5370
# Playing training game 5371
# Playing training game 5372
# Playing training game 5373
# Playing training game 5374
# Playing training game 5375
# Playing training game 5376
# Playing training game 5377
# Playing training game 5378
# Playing training game 5379
# Playing training game 5380
# Playing training game 5381
# Playing training game 5382
# Playing training game 5383
# Playing training game 5384
# Playing training game 5385
# Playing training game 5386
# Playing training game 5387
# Playing training game 5388
# Playing training game 5389
# Playing training game 5390
# Playing training game 5391
# Playing training game 5392
# Playing training game 5393
# Playing training game 5394
# Playing training game 5395
# Playing training game 5396
# Playing training game 5397
# Playing training game 5398
# Playing training game 5399
# Playing training game 5400
# Playing training game 5401
# Playing training game 5402
# Playing training game 5403
# Playing training game 5404
# Playing training game 5405
# Playing training game 5406
# Playing training game 5407
# Playing training game 5408
# Playing training game 5409
# Playing training game 5410
# Playing training game 5411
# Playing training game 5412
# Playing training game 5413
# Playing training game 5414
# Playing training game 5415
# Playing training game 5416
# Playing training game 5417
# Playing training game 5418
# Playing training game 5419
# Playing training game 5420
# Playing training game 5421
# Playing training game 5422
# Playing training game 5423
# Playing training game 5424
# Playing training game 5425
# Playing training game 5426
# Playing training game 5427
# Playing training game 5428
# Playing training game 5429
# Playing training game 5430
# Playing training game 5431
# Playing training game 5432
# Playing training game 5433
# Playing training game 5434
# Playing training game 5435
# Playing training game 5436
# Playing training game 5437
# Playing training game 5438
# Playing training game 5439
# Playing training game 5440
# Playing training game 5441
# Playing training game 5442
# Playing training game 5443
# Playing training game 5444
# Playing training game 5445
# Playing training game 5446
# Playing training game 5447
# Playing training game 5448
# Playing training game 5449
# Playing training game 5450
# Playing training game 5451
# Playing training game 5452
# Playing training game 5453
# Playing training game 5454
# Playing training game 5455
# Playing training game 5456
# Playing training game 5457
# Playing training game 5458
# Playing training game 5459
# Playing training game 5460
# Playing training game 5461
# Playing training game 5462
# Playing training game 5463
# Playing training game 5464
# Playing training game 5465
# Playing training game 5466
# Playing training game 5467
# Playing training game 5468
# Playing training game 5469
# Playing training game 5470
# Playing training game 5471
# Playing training game 5472
# Playing training game 5473
# Playing training game 5474
# Playing training game 5475
# Playing training game 5476
# Playing training game 5477
# Playing training game 5478
# Playing training game 5479
# Playing training game 5480
# Playing training game 5481
# Playing training game 5482
# Playing training game 5483
# Playing training game 5484
# Playing training game 5485
# Playing training game 5486
# Playing training game 5487
# Playing training game 5488
# Playing training game 5489
# Playing training game 5490
# Playing training game 5491
# Playing training game 5492
# Playing training game 5493
# Playing training game 5494
# Playing training game 5495
# Playing training game 5496
# Playing training game 5497
# Playing training game 5498
# Playing training game 5499
# Playing training game 5500
# Playing training game 5501
# Playing training game 5502
# Playing training game 5503
# Playing training game 5504
# Playing training game 5505
# Playing training game 5506
# Playing training game 5507
# Playing training game 5508
# Playing training game 5509
# Playing training game 5510
# Playing training game 5511
# Playing training game 5512
# Playing training game 5513
# Playing training game 5514
# Playing training game 5515
# Playing training game 5516
# Playing training game 5517
# Playing training game 5518
# Playing training game 5519
# Playing training game 5520
# Playing training game 5521
# Playing training game 5522
# Playing training game 5523
# Playing training game 5524
# Playing training game 5525
# Playing training game 5526
# Playing training game 5527
# Playing training game 5528
# Playing training game 5529
# Playing training game 5530
# Playing training game 5531
# Playing training game 5532
# Playing training game 5533
# Playing training game 5534
# Playing training game 5535
# Playing training game 5536
# Playing training game 5537
# Playing training game 5538
# Playing training game 5539
# Playing training game 5540
# Playing training game 5541
# Playing training game 5542
# Playing training game 5543
# Playing training game 5544
# Playing training game 5545
# Playing training game 5546
# Playing training game 5547
# Playing training game 5548
# Playing training game 5549
# Playing training game 5550
# Playing training game 5551
# Playing training game 5552
# Playing training game 5553
# Playing training game 5554
# Playing training game 5555
# Playing training game 5556
# Playing training game 5557
# Playing training game 5558
# Playing training game 5559
# Playing training game 5560
# Playing training game 5561
# Playing training game 5562
# Playing training game 5563
# Playing training game 5564
# Playing training game 5565
# Playing training game 5566
# Playing training game 5567
# Playing training game 5568
# Playing training game 5569
# Playing training game 5570
# Playing training game 5571
# Playing training game 5572
# Playing training game 5573
# Playing training game 5574
# Playing training game 5575
# Playing training game 5576
# Playing training game 5577
# Playing training game 5578
# Playing training game 5579
# Playing training game 5580
# Playing training game 5581
# Playing training game 5582
# Playing training game 5583
# Playing training game 5584
# Playing training game 5585
# Playing training game 5586
# Playing training game 5587
# Playing training game 5588
# Playing training game 5589
# Playing training game 5590
# Playing training game 5591
# Playing training game 5592
# Playing training game 5593
# Playing training game 5594
# Playing training game 5595
# Playing training game 5596
# Playing training game 5597
# Playing training game 5598
# Playing training game 5599
# Playing training game 5600
# Playing training game 5601
# Playing training game 5602
# Playing training game 5603
# Playing training game 5604
# Playing training game 5605
# Playing training game 5606
# Playing training game 5607
# Playing training game 5608
# Playing training game 5609
# Playing training game 5610
# Playing training game 5611
# Playing training game 5612
# Playing training game 5613
# Playing training game 5614
# Playing training game 5615
# Playing training game 5616
# Playing training game 5617
# Playing training game 5618
# Playing training game 5619
# Playing training game 5620
# Playing training game 5621
# Playing training game 5622
# Playing training game 5623
# Playing training game 5624
# Playing training game 5625
# Playing training game 5626
# Playing training game 5627
# Playing training game 5628
# Playing training game 5629
# Playing training game 5630
# Playing training game 5631
# Playing training game 5632
# Playing training game 5633
# Playing training game 5634
# Playing training game 5635
# Playing training game 5636
# Playing training game 5637
# Playing training game 5638
# Playing training game 5639
# Playing training game 5640
# Playing training game 5641
# Playing training game 5642
# Playing training game 5643
# Playing training game 5644
# Playing training game 5645
# Playing training game 5646
# Playing training game 5647
# Playing training game 5648
# Playing training game 5649
# Playing training game 5650
# Playing training game 5651
# Playing training game 5652
# Playing training game 5653
# Playing training game 5654
# Playing training game 5655
# Playing training game 5656
# Playing training game 5657
# Playing training game 5658
# Playing training game 5659
# Playing training game 5660
# Playing training game 5661
# Playing training game 5662
# Playing training game 5663
# Playing training game 5664
# Playing training game 5665
# Playing training game 5666
# Playing training game 5667
# Playing training game 5668
# Playing training game 5669
# Playing training game 5670
# Playing training game 5671
# Playing training game 5672
# Playing training game 5673
# Playing training game 5674
# Playing training game 5675
# Playing training game 5676
# Playing training game 5677
# Playing training game 5678
# Playing training game 5679
# Playing training game 5680
# Playing training game 5681
# Playing training game 5682
# Playing training game 5683
# Playing training game 5684
# Playing training game 5685
# Playing training game 5686
# Playing training game 5687
# Playing training game 5688
# Playing training game 5689
# Playing training game 5690
# Playing training game 5691
# Playing training game 5692
# Playing training game 5693
# Playing training game 5694
# Playing training game 5695
# Playing training game 5696
# Playing training game 5697
# Playing training game 5698
# Playing training game 5699
# Playing training game 5700
# Playing training game 5701
# Playing training game 5702
# Playing training game 5703
# Playing training game 5704
# Playing training game 5705
# Playing training game 5706
# Playing training game 5707
# Playing training game 5708
# Playing training game 5709
# Playing training game 5710
# Playing training game 5711
# Playing training game 5712
# Playing training game 5713
# Playing training game 5714
# Playing training game 5715
# Playing training game 5716
# Playing training game 5717
# Playing training game 5718
# Playing training game 5719
# Playing training game 5720
# Playing training game 5721
# Playing training game 5722
# Playing training game 5723
# Playing training game 5724
# Playing training game 5725
# Playing training game 5726
# Playing training game 5727
# Playing training game 5728
# Playing training game 5729
# Playing training game 5730
# Playing training game 5731
# Playing training game 5732
# Playing training game 5733
# Playing training game 5734
# Playing training game 5735
# Playing training game 5736
# Playing training game 5737
# Playing training game 5738
# Playing training game 5739
# Playing training game 5740
# Playing training game 5741
# Playing training game 5742
# Playing training game 5743
# Playing training game 5744
# Playing training game 5745
# Playing training game 5746
# Playing training game 5747
# Playing training game 5748
# Playing training game 5749
# Playing training game 5750
# Playing training game 5751
# Playing training game 5752
# Playing training game 5753
# Playing training game 5754
# Playing training game 5755
# Playing training game 5756
# Playing training game 5757
# Playing training game 5758
# Playing training game 5759
# Playing training game 5760
# Playing training game 5761
# Playing training game 5762
# Playing training game 5763
# Playing training game 5764
# Playing training game 5765
# Playing training game 5766
# Playing training game 5767
# Playing training game 5768
# Playing training game 5769
# Playing training game 5770
# Playing training game 5771
# Playing training game 5772
# Playing training game 5773
# Playing training game 5774
# Playing training game 5775
# Playing training game 5776
# Playing training game 5777
# Playing training game 5778
# Playing training game 5779
# Playing training game 5780
# Playing training game 5781
# Playing training game 5782
# Playing training game 5783
# Playing training game 5784
# Playing training game 5785
# Playing training game 5786
# Playing training game 5787
# Playing training game 5788
# Playing training game 5789
# Playing training game 5790
# Playing training game 5791
# Playing training game 5792
# Playing training game 5793
# Playing training game 5794
# Playing training game 5795
# Playing training game 5796
# Playing training game 5797
# Playing training game 5798
# Playing training game 5799
# Playing training game 5800
# Playing training game 5801
# Playing training game 5802
# Playing training game 5803
# Playing training game 5804
# Playing training game 5805
# Playing training game 5806
# Playing training game 5807
# Playing training game 5808
# Playing training game 5809
# Playing training game 5810
# Playing training game 5811
# Playing training game 5812
# Playing training game 5813
# Playing training game 5814
# Playing training game 5815
# Playing training game 5816
# Playing training game 5817
# Playing training game 5818
# Playing training game 5819
# Playing training game 5820
# Playing training game 5821
# Playing training game 5822
# Playing training game 5823
# Playing training game 5824
# Playing training game 5825
# Playing training game 5826
# Playing training game 5827
# Playing training game 5828
# Playing training game 5829
# Playing training game 5830
# Playing training game 5831
# Playing training game 5832
# Playing training game 5833
# Playing training game 5834
# Playing training game 5835
# Playing training game 5836
# Playing training game 5837
# Playing training game 5838
# Playing training game 5839
# Playing training game 5840
# Playing training game 5841
# Playing training game 5842
# Playing training game 5843
# Playing training game 5844
# Playing training game 5845
# Playing training game 5846
# Playing training game 5847
# Playing training game 5848
# Playing training game 5849
# Playing training game 5850
# Playing training game 5851
# Playing training game 5852
# Playing training game 5853
# Playing training game 5854
# Playing training game 5855
# Playing training game 5856
# Playing training game 5857
# Playing training game 5858
# Playing training game 5859
# Playing training game 5860
# Playing training game 5861
# Playing training game 5862
# Playing training game 5863
# Playing training game 5864
# Playing training game 5865
# Playing training game 5866
# Playing training game 5867
# Playing training game 5868
# Playing training game 5869
# Playing training game 5870
# Playing training game 5871
# Playing training game 5872
# Playing training game 5873
# Playing training game 5874
# Playing training game 5875
# Playing training game 5876
# Playing training game 5877
# Playing training game 5878
# Playing training game 5879
# Playing training game 5880
# Playing training game 5881
# Playing training game 5882
# Playing training game 5883
# Playing training game 5884
# Playing training game 5885
# Playing training game 5886
# Playing training game 5887
# Playing training game 5888
# Playing training game 5889
# Playing training game 5890
# Playing training game 5891
# Playing training game 5892
# Playing training game 5893
# Playing training game 5894
# Playing training game 5895
# Playing training game 5896
# Playing training game 5897
# Playing training game 5898
# Playing training game 5899
# Playing training game 5900
# Playing training game 5901
# Playing training game 5902
# Playing training game 5903
# Playing training game 5904
# Playing training game 5905
# Playing training game 5906
# Playing training game 5907
# Playing training game 5908
# Playing training game 5909
# Playing training game 5910
# Playing training game 5911
# Playing training game 5912
# Playing training game 5913
# Playing training game 5914
# Playing training game 5915
# Playing training game 5916
# Playing training game 5917
# Playing training game 5918
# Playing training game 5919
# Playing training game 5920
# Playing training game 5921
# Playing training game 5922
# Playing training game 5923
# Playing training game 5924
# Playing training game 5925
# Playing training game 5926
# Playing training game 5927
# Playing training game 5928
# Playing training game 5929
# Playing training game 5930
# Playing training game 5931
# Playing training game 5932
# Playing training game 5933
# Playing training game 5934
# Playing training game 5935
# Playing training game 5936
# Playing training game 5937
# Playing training game 5938
# Playing training game 5939
# Playing training game 5940
# Playing training game 5941
# Playing training game 5942
# Playing training game 5943
# Playing training game 5944
# Playing training game 5945
# Playing training game 5946
# Playing training game 5947
# Playing training game 5948
# Playing training game 5949
# Playing training game 5950
# Playing training game 5951
# Playing training game 5952
# Playing training game 5953
# Playing training game 5954
# Playing training game 5955
# Playing training game 5956
# Playing training game 5957
# Playing training game 5958
# Playing training game 5959
# Playing training game 5960
# Playing training game 5961
# Playing training game 5962
# Playing training game 5963
# Playing training game 5964
# Playing training game 5965
# Playing training game 5966
# Playing training game 5967
# Playing training game 5968
# Playing training game 5969
# Playing training game 5970
# Playing training game 5971
# Playing training game 5972
# Playing training game 5973
# Playing training game 5974
# Playing training game 5975
# Playing training game 5976
# Playing training game 5977
# Playing training game 5978
# Playing training game 5979
# Playing training game 5980
# Playing training game 5981
# Playing training game 5982
# Playing training game 5983
# Playing training game 5984
# Playing training game 5985
# Playing training game 5986
# Playing training game 5987
# Playing training game 5988
# Playing training game 5989
# Playing training game 5990
# Playing training game 5991
# Playing training game 5992
# Playing training game 5993
# Playing training game 5994
# Playing training game 5995
# Playing training game 5996
# Playing training game 5997
# Playing training game 5998
# Playing training game 5999
# Playing training game 6000
# Playing training game 6001
# Playing training game 6002
# Playing training game 6003
# Playing training game 6004
# Playing training game 6005
# Playing training game 6006
# Playing training game 6007
# Playing training game 6008
# Playing training game 6009
# Playing training game 6010
# Playing training game 6011
# Playing training game 6012
# Playing training game 6013
# Playing training game 6014
# Playing training game 6015
# Playing training game 6016
# Playing training game 6017
# Playing training game 6018
# Playing training game 6019
# Playing training game 6020
# Playing training game 6021
# Playing training game 6022
# Playing training game 6023
# Playing training game 6024
# Playing training game 6025
# Playing training game 6026
# Playing training game 6027
# Playing training game 6028
# Playing training game 6029
# Playing training game 6030
# Playing training game 6031
# Playing training game 6032
# Playing training game 6033
# Playing training game 6034
# Playing training game 6035
# Playing training game 6036
# Playing training game 6037
# Playing training game 6038
# Playing training game 6039
# Playing training game 6040
# Playing training game 6041
# Playing training game 6042
# Playing training game 6043
# Playing training game 6044
# Playing training game 6045
# Playing training game 6046
# Playing training game 6047
# Playing training game 6048
# Playing training game 6049
# Playing training game 6050
# Playing training game 6051
# Playing training game 6052
# Playing training game 6053
# Playing training game 6054
# Playing training game 6055
# Playing training game 6056
# Playing training game 6057
# Playing training game 6058
# Playing training game 6059
# Playing training game 6060
# Playing training game 6061
# Playing training game 6062
# Playing training game 6063
# Playing training game 6064
# Playing training game 6065
# Playing training game 6066
# Playing training game 6067
# Playing training game 6068
# Playing training game 6069
# Playing training game 6070
# Playing training game 6071
# Playing training game 6072
# Playing training game 6073
# Playing training game 6074
# Playing training game 6075
# Playing training game 9890
# Playing training game 9891
# Playing training game 9892
# Playing training game 9893
# Playing training game 9894
# Playing training game 9895
# Playing training game 9896
# Playing training game 9897
# Playing training game 9898
# Playing training game 9899
# Playing training game 9900
# Playing training game 9901
# Playing training game 9902
# Playing training game 9903
# Playing training game 9904
# Playing training game 9905
# Playing training game 9906
# Playing training game 9907
# Playing training game 9908
# Playing training game 9909
# Playing training game 9910
# Playing training game 9911
# Playing training game 9912
# Playing training game 9913
# Playing training game 9914
# Playing training game 9915
# Playing training game 9916
# Playing training game 9917
# Playing training game 9918
# Playing training game 9919
# Playing training game 9920
# Playing training game 9921
# Playing training game 9922
# Playing training game 9923
# Playing training game 9924
# Playing training game 9925
# Playing training game 9926
# Playing training game 9927
# Playing training game 9928
# Playing training game 9929
# Playing training game 9930
# Playing training game 9931
# Playing training game 9932
# Playing training game 9933
# Playing training game 9934
# Playing training game 9935
# Playing training game 9936
# Playing training game 9937
# Playing training game 9938
# Playing training game 9939
# Playing training game 9940
# Playing training game 9941
# Playing training game 9942
# Playing training game 9943
# Playing training game 9944
# Playing training game 9945
# Playing training game 9946
# Playing training game 9947
# Playing training game 9948
# Playing training game 9949
# Playing training game 9950
# Playing training game 9951
# Playing training game 9952
# Playing training game 9953
# Playing training game 9954
# Playing training game 9955
# Playing training game 9956
# Playing training game 9957
# Playing training game 9958
# Playing training game 9959
# Playing training game 9960
# Playing training game 9961
# Playing training game 9962
# Playing training game 9963
# Playing training game 9964
# Playing training game 9965
# Playing training game 9966
# Playing training game 9967
# Playing training game 9968
# Playing training game 9969
# Playing training game 9970
# Playing training game 9971
# Playing training game 9972
# Playing training game 9973
# Playing training game 9974
# Playing training game 9975
# Playing training game 9976
# Playing training game 9977
# Playing training game 9978
# Playing training game 9979
# Playing training game 9980
# Playing training game 9981
# Playing training game 9982
# Playing training game 9983
# Playing training game 9984
# Playing training game 9985
# Playing training game 9986
# Playing training game 9987
# Playing training game 9988
# Playing training game 9989
# Playing training game 9990
# Playing training game 9991
# Playing training game 9992
# Playing training game 9993
# Playing training game 9994
# Playing training game 9995
# Playing training game 9996
# Playing training game 9997
# Playing training game 9998
# Playing training game 9999
# Playing training game 10000
# Done training
#
# Piles:
# Pile 0: 1
# Pile 1: 3
# Pile 2: 5
# Pile 3: 7
#
# Your Turn
# Choose Pile: 3
# Choose Count: 7
#
# Piles:
# Pile 0: 1
# Pile 1: 3
# Pile 2: 5
# Pile 3: 0
#
# AI's Turn
# AI chose to take 3 from pile 2.
#
# Piles:
# Pile 0: 1
# Pile 1: 3
# Pile 2: 2
# Pile 3: 0
#
# Your Turn
# Choose Pile: 1
# Choose Count: 3
#
# Piles:
# Pile 0: 1
# Pile 1: 0
# Pile 2: 2
# Pile 3: 0
#
# AI's Turn
# AI chose to take 2 from pile 2.
#
# Piles:
# Pile 0: 1
# Pile 1: 0
# Pile 2: 0
# Pile 3: 0
#
# Your Turn
# Choose Pile: 0
# Choose Count: 1
#
# GAME OVER
# Winner is AI
